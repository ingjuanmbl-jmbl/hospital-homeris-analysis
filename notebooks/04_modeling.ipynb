# %%
import pandas as pd
import numpy as np
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.utils import read_csv

# %%
df = read_csv("../data/PCA/homeris-data-clean-preprocessed-PCA.csv")
df.head(4)
# Out:
# Archivo cargado existosamente desde: ../data/PCA/homeris-data-clean-preprocessed-PCA.csv
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  1.742974  0.656531 -0.913923 -0.369159 -0.376690 -0.051812  0.785666
# 1  0.583638 -0.685008  0.520801 -0.217924 -0.218349 -0.056699 -0.010767
# 2 -1.409546 -0.592317  0.410423 -0.293166 -0.240198 -0.015030 -0.026376
# 3  0.656064  0.718861  0.443332 -0.179581 -0.224305 -0.019678 -0.048199
#
#         PC8       PC9      PC10  ...      PC32      PC33      PC34      PC35  \
# 0 -0.121601  0.116115  0.034575  ...  0.029750  0.054293  0.036549  0.026133
# 1 -0.024844 -0.143039 -0.022742  ... -0.017385  0.024439  0.076805  0.026515
# 2 -0.059698 -0.149407 -0.031032  ...  0.014708  0.086667  0.024795  0.077183
# 3 -0.034328 -0.149973 -0.015612  ... -0.001314  0.176087  0.202168  0.069321
#
#        PC36      PC37      PC38      PC39      PC40      PC41
# 0 -0.035154 -0.022937  0.028335  0.013609  0.018446  0.005791
# ...

# %%
from src.modeling import optimizar_algoritmo, entrenar_algoritmos

# %%
df_metricas, modelo_final,  mejor = entrenar_algoritmos(df)
# Out:
# Analizando KMEANS...
# Analizando AC...
# Analizando GMM...

# %%
mejor
# Out:
# {'modelo': 'kmeans',
#  'k': 2,
#  'silhouette': 0.2640559056066659,
#  'calinski_harabasz': 6759.555047854096}

# %%
from src.utils import save_csv, save_artifact

# %%
save_csv(df_metricas,"../data/best_model_result/best_model_result.csv")
# Out:
# DataFrame guardado existosamente en la ruta: ../data/best_model_result/best_model_result.csv

# %%
help(save_artifact)
# Out:
# Help on function save_artifact in module src.utils:
#
# save_artifact(obj, name, artifacts_type)
#     Guarda un objeto de Python (modelo, encoder, scaler, etc.) en una subcarpeta específica
#     dentro del directorio de 'artifacts'.
#         Args:
#             obj: obj (any): El objeto de Python que se desea persistir (ej. un modelo de KMeans o un OrdinalEncoder).
#             name (str): El nombre que se le dará al archivo (sin la extensión .joblib).
#             artifacts_type (str): El nombre de la subcarpeta donde se guardará.
#         Returns:
#             pathlib.Path: La ruta completa donde se guardó el archivo.

# %%
save_artifact(modelo_final, "Best_model_ns","../artifacts/models")
# Out:
# Objeto correctamente cargado en: C:\Users\JM\Documents\Proyectos\open_data\hospital-homeris-analysis\artifacts\..\artifacts\models\Best_model_ns.joblib
# WindowsPath('C:/Users/JM/Documents/Proyectos/open_data/hospital-homeris-analysis/artifacts/../artifacts/models/Best_model_ns.joblib')
